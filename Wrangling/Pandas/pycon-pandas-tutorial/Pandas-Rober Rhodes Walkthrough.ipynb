# %% [markdown]
# # Pandas Walkthrough
#
# ### Resource:
#
# - Robert Rhodes

# %% [markdown]
# # Section 1:
#
# ## Contents:
#
# - len(def)
# - df.head()
# - df.tail()
# - df.COLUMN
# - df['COLUMN']
# - series + value
# - series + series2
# - series.notnull()
# - series.isnull
# - series.order() *#obsolete*
# - series.sort_values('column')
# - df[df.c == value]
# - df[(df.c >= value1) & (df.c < value2)]
# - df.sort('column') *#obsolete*
# - df.sort(['column1', 'column2']) *#obsolete*
# - df.sort_values('column')

# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.DataFrame.from_csv('data/titles.csv', index_col=None, encoding='UTF-8')
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None, encoding='UTF-8')

# %%
len(titles)
# Out:
# 230621

# %%
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
titles.head(8)
# Out:
#                             title  year
# 0                  The Rising Son  1990
# 1         The Thousand Plane Raid  1969
# 2                Crucea de piatra  1993
# 3                         Country  2000
# 4                      Gaiking II  2011
# 5                     Medusa (IV)  2015
# 6  The Fresh Air Will Do You Good  2008
# 7              Alex in Wonderland  1970

# %%
titles.tail(3)
# Out:
#                                        title  year
# 230618                          Lakota Girls  2015
# 230619                        Kroniki domowe  1997
# 230620  Death in the Valley of Good and Evil  2018

# %%
h = titles.head(5)
h
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
h['title']
# Out:
# 0             The Rising Son
# 1    The Thousand Plane Raid
# 2           Crucea de piatra
# 3                    Country
# 4                 Gaiking II
# Name: title, dtype: object

# %%
h['year']
# Out:
# 0    1990
# 1    1969
# 2    1993
# 3    2000
# 4    2011
# Name: year, dtype: int64

# %%
h['year'] // 10 * 10
# Out:
# 0    1990
# 1    1960
# 2    1990
# 3    2000
# 4    2010
# Name: year, dtype: int64

# %%
h.year
# Out:
# 0    1990
# 1    1969
# 2    1993
# 3    2000
# 4    2011
# Name: year, dtype: int64

# %%
h.year > 1985
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: year, dtype: bool

# %%
h.year > 1985
# Out:
# 0    1990
# 1    1969
# 2    1993
# 3    2000
# 4    2011
# Name: year, dtype: int64

# %%
h[h.year < 2000]
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993

# %%
# don't use 'and' or '&&' instead of '&'
# use parantheses for each statement
h[(h.year > 1970) & (h.year < 2000)]
# Out:
#               title  year
# 0    The Rising Son  1990
# 2  Crucea de piatra  1993

# %%
t = titles

# %%
t[t.title == 'Macbeth'].sort_values(by='year')
# Out:
#           title  year
# 4162    Macbeth  1913
# 67313   Macbeth  1916
# 157917  Macbeth  1948
# 203220  Macbeth  1987
# 16930   Macbeth  1997
# 25430   Macbeth  1998
# 86470   Macbeth  2003
# 131922  Macbeth  2004
# 55416   Macbeth  2006
# 150447  Macbeth  2009
# 11539   Macbeth  2013
# 154409  Macbeth  2014
# 125469  Macbeth  2015
# 146810  Macbeth  2016
# 168225  Macbeth  2017

# %%
t[t.title == 'Macbeth'].sort_values(by='year', ascending=False)
# Out:
#           title  year
# 168225  Macbeth  2017
# 146810  Macbeth  2016
# 125469  Macbeth  2015
# 154409  Macbeth  2014
# 11539   Macbeth  2013
# 150447  Macbeth  2009
# 55416   Macbeth  2006
# 131922  Macbeth  2004
# 86470   Macbeth  2003
# 25430   Macbeth  1998
# 16930   Macbeth  1997
# 203220  Macbeth  1987
# 157917  Macbeth  1948
# 67313   Macbeth  1916
# 4162    Macbeth  1913

# %%
t[t.title == 'Macbeth'].sort_values(by='year').head()
# Out:
#           title  year
# 4162    Macbeth  1913
# 67313   Macbeth  1916
# 157917  Macbeth  1948
# 203220  Macbeth  1987
# 16930   Macbeth  1997

# %%
t[t.title == 'Macbeth'].sort_values(by='year').tail()
# Out:
#           title  year
# 11539   Macbeth  2013
# 154409  Macbeth  2014
# 125469  Macbeth  2015
# 146810  Macbeth  2016
# 168225  Macbeth  2017

# %%
t.year
# Out:
# 0         1990
# 1         1969
# 2         1993
# 3         2000
# 4         2011
# 5         2015
# 6         2008
# 7         1970
# 8         2016
# 9         2008
# 10        2017
# 11        2014
# 12        1996
# 13        1943
# 14        1973
# 15        2002
# 16        1976
# 17        2012
# 18        1965
# 19        1999
# 20        1917
# 21        2009
# 22        1989
# 23        1993
# 24        2011
# 25        1916
# 26        1990
# 27        2001
# 28        2013
# 29        2012
#           ...
# 230591    2014
# 230592    2007
# 230593    1980
# 230594    1990
# 230595    2015
# 230596    1981
# 230597    2008
# 230598    1980
# 230599    2013
# 230600    2013
# 230601    1991
# 230602    1932
# 230603    1986
# 230604    1961
# 230605    1967
# 230606    2004
# 230607    1981
# 230608    2013
# 230609    2016
# 230610    2004
# 230611    1984
# 230612    2012
# 230613    2001
# 230614    1973
# 230615    1982
# 230616    1964
# 230617    2005
# ...

# %%
t.year.sort_values()
# Out:
# 176477    1894
# 213694    1898
# 123627    1899
# 182202    1900
# 94335     1900
# 20499     1900
# 13505     1900
# 207574    1903
# 67675     1905
# 32458     1905
# 28006     1906
# 165033    1906
# 192087    1906
# 212444    1906
# 144106    1906
# 126776    1907
# 204703    1907
# 63074     1907
# 215085    1907
# 129917    1908
# 224076    1908
# 228583    1908
# 171737    1908
# 51033     1908
# 110149    1908
# 76103     1909
# 88419     1909
# 78368     1909
# 92509     1909
# 132100    1909
#           ...
# 201515    2022
# 168929    2022
# 66518     2022
# 76795     2022
# 140604    2022
# 27278     2022
# 216165    2022
# 159641    2022
# 203617    2022
# 11178     2022
# 24402     2022
# 43162     2022
# 87799     2022
# 17902     2022
# 26367     2022
# 175168    2022
# 105445    2023
# 102920    2023
# 195252    2023
# 60981     2023
# 84800     2023
# 129223    2023
# 72041     2023
# 57164     2023
# 32955     2023
# 151139    2023
# 69547     2023
# ...

# %%
h = cast.head()
h
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
h[h.n.notnull()]
# Out:
#                  title  year     name   type        character     n
# 1      Suuri illusioni  1985   Homo $  actor           Guests  22.0
# 2  Battle of the Sexes  2017  $hutter  actor  Bobby Riggs Fan  10.0

# %%
h[h.n.isnull()]
# Out:
#                   title  year      name   type                character   n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4 NaN
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron NaN

# %% [markdown]
# # Section 2:
#
# ## Contents:
#
# - s.str.len()
# - sstr.contains()
# - s.str.startwith()
# - series.value_counts()
# - series.sort_index()
# - series.plot()
# - df.[['col1', 'col2', ...]]
# - df.plot(x='a', y='b', kind='bar')

# %%
t = titles
t[t.title == 'Hamlet']
# Out:
#          title  year
# 5969    Hamlet  1948
# 45010   Hamlet  1990
# 46365   Hamlet  1910
# 91506   Hamlet  1976
# 93696   Hamlet  1987
# 93894   Hamlet  2000
# 97869   Hamlet  1921
# 102208  Hamlet  2011
# 121837  Hamlet  1969
# 127468  Hamlet  1954
# 165217  Hamlet  1913
# 167748  Hamlet  2015
# 174816  Hamlet  2009
# 181662  Hamlet  1964
# 199837  Hamlet  1996
# 208366  Hamlet  1911
# 219855  Hamlet  1973
# 221923  Hamlet  2014

# %%
t = titles
t[t['title'].str.contains('Hamlet')]
# Out:
#                                           title  year
# 4368            Dogg's Hamlet, Cahoot's Macbeth  2005
# 5969                                     Hamlet  1948
# 7598                  Hamlet: Prince of Denmark  1989
# 8511                                Hamlet (II)  2005
# 8794                                Hamlet (II)  2015
# 14211                     Green Eggs and Hamlet  1995
# 15076                            Hamlet Unbound  2012
# 15096             Hamlet: The Fall of a Sparrow  2017
# 17291                 Hamlet, Prince of Denmark  1997
# 23994                        Han, hun og Hamlet  1932
# 24099               Intikam Melegi/Kadin Hamlet  1976
# 36856                                  Hamlet_X  2003
# 38935                  Hamlet, Son of a Kingpin  2015
# 41947                               Hamlet (IV)  2016
# 44351                              Hamlet (III)  2007
# 45010                                    Hamlet  1990
# ...

# %%
t = titles
t[t.title.str.startswith('Hamlet')]
# Out:
#                                 title  year
# 5969                           Hamlet  1948
# 7598        Hamlet: Prince of Denmark  1989
# 8511                      Hamlet (II)  2005
# 8794                      Hamlet (II)  2015
# 15076                  Hamlet Unbound  2012
# 15096   Hamlet: The Fall of a Sparrow  2017
# 17291       Hamlet, Prince of Denmark  1997
# 36856                        Hamlet_X  2003
# 38935        Hamlet, Son of a Kingpin  2015
# 41947                     Hamlet (IV)  2016
# 44351                    Hamlet (III)  2007
# 45010                          Hamlet  1990
# 46365                          Hamlet  1910
# 91506                          Hamlet  1976
# 93696                          Hamlet  1987
# 93894                          Hamlet  2000
# 97401                        Hamlet 2  2008
# 97869                          Hamlet  1921
# 102208                         Hamlet  2011
# 108617                  Hamlet Frezer  2016
# ...

# %%
t = titles
t[t.title.str.endswith('Hamlet')]
# Out:
#                                     title  year
# 5969                               Hamlet  1948
# 14211               Green Eggs and Hamlet  1995
# 23994                  Han, hun og Hamlet  1932
# 24099         Intikam Melegi/Kadin Hamlet  1976
# 45010                              Hamlet  1990
# 46365                              Hamlet  1910
# 62081                      Redneck Hamlet  2017
# 72379                  A Sagebrush Hamlet  1919
# 91506                              Hamlet  1976
# 93696                              Hamlet  1987
# 93894                              Hamlet  2000
# 97869                              Hamlet  1921
# 98704                  Han, hun og Hamlet  1922
# 102208                             Hamlet  2011
# 121837                             Hamlet  1969
# 127468                             Hamlet  1954
# 150832                        Fuck Hamlet  1996
# 165217                             Hamlet  1913
# 166656                      Zombie Hamlet  2012
# ...

# %%
t = titles
es
t.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
t.year
# Out:
# 0         1990
# 1         1969
# 2         1993
# 3         2000
# 4         2011
# 5         2015
# 6         2008
# 7         1970
# 8         2016
# 9         2008
# 10        2017
# 11        2014
# 12        1996
# 13        1943
# 14        1973
# 15        2002
# 16        1976
# 17        2012
# 18        1965
# 19        1999
# 20        1917
# 21        2009
# 22        1989
# 23        1993
# 24        2011
# 25        1916
# 26        1990
# 27        2001
# 28        2013
# 29        2012
#           ...
# 230591    2014
# 230592    2007
# 230593    1980
# 230594    1990
# 230595    2015
# 230596    1981
# 230597    2008
# 230598    1980
# 230599    2013
# 230600    2013
# 230601    1991
# 230602    1932
# 230603    1986
# 230604    1961
# 230605    1967
# 230606    2004
# 230607    1981
# 230608    2013
# 230609    2016
# 230610    2004
# 230611    1984
# 230612    2012
# 230613    2001
# 230614    1973
# 230615    1982
# 230616    1964
# 230617    2005
# ...

# %%
t.year.value_counts()
# Out:
# 2016    11061
# 2015     8664
# 2017     8379
# 2014     8076
# 2013     7674
# 2012     7262
# 2011     6867
# 2010     6267
# 2009     6030
# 2008     5022
# 2007     4347
# 2006     4197
# 2005     3939
# 2004     3446
# 2003     3116
# 2002     2965
# 2001     2838
# 2000     2736
# 1999     2496
# 1998     2388
# 1997     2306
# 1988     2299
# 1990     2290
# 1991     2247
# 1989     2234
# 1987     2210
# 1969     2159
# 1992     2156
# 1970     2144
# 1996     2109
#         ...
# 1924      801
# 1946      781
# 1943      762
# 1929      754
# 1923      730
# 1944      722
# 1945      647
# 1914      555
# 2019      372
# 1913      248
# 2020      125
# 1912      110
# 1911       57
# 2021       23
# 1910       22
# 2022       18
# 1909       15
# 2023       11
# 1908        6
# 1906        5
# 1907        4
# 1900        4
# 1905        2
# 1894        1
# 1903        1
# 1899        1
# 2026        1
# 1898        1
# 2025        1
# 2024        1
# ...

# %%
t.year.value_counts().sort_index()
# Out:
# 1894        1
# 1898        1
# 1899        1
# 1900        4
# 1903        1
# 1905        2
# 1906        5
# 1907        4
# 1908        6
# 1909       15
# 1910       22
# 1911       57
# 1912      110
# 1913      248
# 1914      555
# 1915      885
# 1916     1177
# 1917     1196
# 1918     1096
# 1919     1152
# 1920     1126
# 1921      972
# 1922      892
# 1923      730
# 1924      801
# 1925      880
# 1926      869
# 1927      868
# 1928      891
# 1929      754
#         ...
# 1997     2306
# 1998     2388
# 1999     2496
# 2000     2736
# 2001     2838
# 2002     2965
# 2003     3116
# 2004     3446
# 2005     3939
# 2006     4197
# 2007     4347
# 2008     5022
# 2009     6030
# 2010     6267
# 2011     6867
# 2012     7262
# 2013     7674
# 2014     8076
# 2015     8664
# 2016    11061
# 2017     8379
# 2018     2081
# 2019      372
# 2020      125
# 2021       23
# 2022       18
# 2023       11
# 2024        1
# 2025        1
# 2026        1
# ...

# %%
t.year.value_counts().sort_index().plot()

# %%
c = cast
c.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c = c[c.character == 'Kermit the Frog']
c
# Out:
#                                   title  year            name   type  \
# 947844   An American Werewolf in London  1981      Jim Henson  actor
# 947845                 Follow That Bird  1985      Jim Henson  actor
# 947850           The Great Muppet Caper  1981      Jim Henson  actor
# 947858                 The Muppet Movie  1979      Jim Henson  actor
# 947865       The Muppets Take Manhattan  1984      Jim Henson  actor
# 2349148  Mr. Magorium's Wonder Emporium  2007  Steve Whitmire  actor
# 2349149          Muppet Treasure Island  1996  Steve Whitmire  actor
# 2349152              Muppets from Space  1999  Steve Whitmire  actor
# 2349158             Muppets Most Wanted  2014  Steve Whitmire  actor
#
#                character     n
# 947844   Kermit the Frog  18.0
# 947845   Kermit the Frog   2.0
# 947850   Kermit the Frog   1.0
# 947858   Kermit the Frog   1.0
# 947865   Kermit the Frog   1.0
# 2349148  Kermit the Frog   8.0
# 2349149  Kermit the Frog  10.0
# ...

# %%
c.plot(x='year', y='n', kind='bar')

# %% [markdown]
#  # Section 3:
#
#  ## Contents:
#
#  - df.loc['value']
#  - df.loc[('v', 'u')]
#  - df.set_index('col').sort_index()
#  - df.set_index(['col1, 'col2']).sort_index()
#  - df.groupby('col')   .size()  .min()  .max()  .mean()
#  - df,groupby(['col1', 'col2'])

# %%
import hashlib

# %%
c = cast
c.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
len(c)
# Out:
# 3611212

# %%
# %%time
c[c.title == 'Sleuth']
# Out:
# Wall time: 943 ms
#           title  year                 name     type  \
# 250297   Sleuth  2007      Kenneth Branagh    actor
# 314691   Sleuth  1972        Michael Caine    actor
# 314692   Sleuth  2007        Michael Caine    actor
# 360365   Sleuth  1972       Alec Cawthorne    actor
# 360366   Sleuth  2007  Alec (II) Cawthorne    actor
# 1246855  Sleuth  2007             Jude Law    actor
# 1396572  Sleuth  1972         Teddy Martin    actor
# 1412647  Sleuth  1972   John (II) Matthews    actor
# 1644328  Sleuth  1972     Laurence Olivier    actor
# 1741124  Sleuth  2007        Harold Pinter    actor
# 2619277  Sleuth  2007    Eve (II) Channing  actress
# 2619278  Sleuth  1972   Eve (III) Channing  actress
# 3223502  Sleuth  2007    Carmel O'Sullivan  actress
#
#                           character    n
# 250297            Other Man on T.V.  NaN
# 314691                  Milo Tindle  2.0
# 314692                       Andrew  1.0
# 360365            Inspector Doppler  3.0
# ...

# %%
c = cast.set_index('title')
c
# Out:
#                                                    year  \
# title
# Closet Monster                                     2015
# Suuri illusioni                                    1985
# Battle of the Sexes                                2017
# Secret in Their Eyes                               2015
# Steve Jobs                                         2015
# Straight Outta Compton                             2015
# Straight Outta Compton                             2015
# For Thy Love 2                                     2009
# Lapis, Ballpen at Diploma, a True to Life Journey  2014
# Desire (III)                                       2014
# When the Man Went South                            2014
# Little Angel (Angelita)                            2015
# Mixing Nia                                         1998
# The Replacements                                   2000
# All Out Dysfunktion!                               2016
# Gook                                               2017
# ...

# %%
# %%time
c.loc['Sleuth']
# Out:
# Wall time: 1.82 s
#         year                 name     type                   character    n
# title
# Sleuth  2007      Kenneth Branagh    actor           Other Man on T.V.  NaN
# Sleuth  1972        Michael Caine    actor                 Milo Tindle  2.0
# Sleuth  2007        Michael Caine    actor                      Andrew  1.0
# Sleuth  1972       Alec Cawthorne    actor           Inspector Doppler  3.0
# Sleuth  2007  Alec (II) Cawthorne    actor           Inspector Doppler  NaN
# Sleuth  2007             Jude Law    actor                        Milo  2.0
# Sleuth  1972         Teddy Martin    actor      Police Constable Higgs  6.0
# Sleuth  1972   John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# Sleuth  1972     Laurence Olivier    actor                 Andrew Wyke  1.0
# Sleuth  2007        Harold Pinter    actor                 Man on T.V.  3.0
# Sleuth  2007    Eve (II) Channing  actress             Marguerite Wyke  NaN
# ...

# %%
# %%time
c = cast.set_index('title').sort_index()
c
# Out:
# Wall time: 13.7 s

# %%
# %%time
c.loc['The Wizard of Oz']
# Out:
# Wall time: 1e+03 µs
#                   year                   name     type  \
# title
# The Wizard of Oz  1939          Charles Irwin    actor
# The Wizard of Oz  1939             Lee Murray    actor
# The Wizard of Oz  1939           Fern Formica  actress
# The Wizard of Oz  1939           Fern Formica  actress
# The Wizard of Oz  1939           Betty Tanner  actress
# The Wizard of Oz  1939           Joan Kenmore  actress
# The Wizard of Oz  1925      Frederick Ko Vert    actor
# The Wizard of Oz  1939          Franz Balluck    actor
# The Wizard of Oz  1939            Jerry Maren    actor
# The Wizard of Oz  1925       Virginia Pearson  actress
# The Wizard of Oz  1925        Frank Alexander    actor
# The Wizard of Oz  1939            Elaine Merk  actress
# The Wizard of Oz  1939          George Noisom    actor
# The Wizard of Oz  1925        Chester Conklin    actor
# The Wizard of Oz  1939           Lois January  actress
# ...

# %%
c = cast.set_index(['title', 'year'])
c.head()
# Out:
#                                name   type                character     n
# title                year
# Closet Monster       2015  Buffy #1  actor                  Buffy 4   NaN
# Suuri illusioni      1985    Homo $  actor                   Guests  22.0
# Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# Secret in Their Eyes 2015   $hutter  actor          2002 Dodger Fan   NaN
# Steve Jobs           2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
# %%time
c.loc['Sleuth']
# Out:
# Wall time: 25 ms
#                      name     type                   character    n
# year
# 2007      Kenneth Branagh    actor           Other Man on T.V.  NaN
# 1972        Michael Caine    actor                 Milo Tindle  2.0
# 2007        Michael Caine    actor                      Andrew  1.0
# 1972       Alec Cawthorne    actor           Inspector Doppler  3.0
# 2007  Alec (II) Cawthorne    actor           Inspector Doppler  NaN
# 2007             Jude Law    actor                        Milo  2.0
# 1972         Teddy Martin    actor      Police Constable Higgs  6.0
# 1972   John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# 1972     Laurence Olivier    actor                 Andrew Wyke  1.0
# 2007        Harold Pinter    actor                 Man on T.V.  3.0
# 2007    Eve (II) Channing  actress             Marguerite Wyke  NaN
# 1972   Eve (III) Channing  actress             Marguerite Wyke  5.0
# ...

# %%
# %%time
c.loc['Sleuth'].loc[1972]
# Out:
# Wall time: 29 ms
#                     name     type                   character    n
# year
# 1972       Michael Caine    actor                 Milo Tindle  2.0
# 1972      Alec Cawthorne    actor           Inspector Doppler  3.0
# 1972        Teddy Martin    actor      Police Constable Higgs  6.0
# 1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# 1972    Laurence Olivier    actor                 Andrew Wyke  1.0
# 1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
# %%time
c.loc[('Sleuth', 1972)]
# Out:
# Wall time: 51 ms
# C:\Users\hossein\Anaconda3\envs\py27\lib\site-packages\ipykernel\__main__.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if __name__ == '__main__':
#                            name     type                   character    n
# title  year
# Sleuth 1972       Michael Caine    actor                 Milo Tindle  2.0
#        1972      Alec Cawthorne    actor           Inspector Doppler  3.0
#        1972        Teddy Martin    actor      Police Constable Higgs  6.0
#        1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
#        1972    Laurence Olivier    actor                 Andrew Wyke  1.0
#        1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
c.loc[('Sleuth', 1972)].reset_index('year')
# Out:
# C:\Users\hossein\Anaconda3\envs\py27\lib\site-packages\ipykernel\__main__.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if __name__ == '__main__':
#         year                name     type                   character    n
# title
# Sleuth  1972       Michael Caine    actor                 Milo Tindle  2.0
# Sleuth  1972      Alec Cawthorne    actor           Inspector Doppler  3.0
# Sleuth  1972        Teddy Martin    actor      Police Constable Higgs  6.0
# Sleuth  1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# Sleuth  1972    Laurence Olivier    actor                 Andrew Wyke  1.0
# Sleuth  1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
c.loc[('Sleuth', 1972)].reset_index(['title', 'year'])
# Out:
# C:\Users\hossein\Anaconda3\envs\py27\lib\site-packages\ipykernel\__main__.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if __name__ == '__main__':
#     title  year                name     type                   character    n
# 0  Sleuth  1972       Michael Caine    actor                 Milo Tindle  2.0
# 1  Sleuth  1972      Alec Cawthorne    actor           Inspector Doppler  3.0
# 2  Sleuth  1972        Teddy Martin    actor      Police Constable Higgs  6.0
# 3  Sleuth  1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# 4  Sleuth  1972    Laurence Olivier    actor                 Andrew Wyke  1.0
# 5  Sleuth  1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
c.head()
# Out:
#                                name   type                character     n
# title                year
# Closet Monster       2015  Buffy #1  actor                  Buffy 4   NaN
# Suuri illusioni      1985    Homo $  actor                   Guests  22.0
# Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# Secret in Their Eyes 2015   $hutter  actor          2002 Dodger Fan   NaN
# Steve Jobs           2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c = cast[cast.name == 'George Clooney']
c.head()
# Out:
#                                   title  year            name   type  \
# 419772          A Very Murray Christmas  2015  George Clooney  actor
# 419773                   Batman & Robin  1997  George Clooney  actor
# 419774                   Batman & Robin  1997  George Clooney  actor
# 419775               Burn After Reading  2008  George Clooney  actor
# 419776  Confessions of a Dangerous Mind  2002  George Clooney  actor
#
#              character     n
# 419772  George Clooney   4.0
# 419773          Batman   2.0
# 419774     Bruce Wayne   2.0
# 419775   Harry Pfarrer   1.0
# 419776        Jim Byrd  17.0

# %%
c.groupby(['title', 'year', 'character']).size()
# Out:
# title                               year  character
# A Very Murray Christmas             2015  George Clooney              1
# Batman & Robin                      1997  Batman                      1
#                                           Bruce Wayne                 1
# Burn After Reading                  2008  Harry Pfarrer               1
# Confessions of a Dangerous Mind     2002  Jim Byrd                    1
# Curdled                             1996  Seth Gecko                  1
# Fantastic Mr. Fox                   2009  Mr. Fox                     1
# From Dusk Till Dawn                 1996  Seth Gecko                  1
# Good Night, and Good Luck.          2005  Fred Friendly               1
# Gravity                             2013  Matt Kowalski               1
# Hail, Caesar!                       2016  Baird Whitlock              1
# Intolerable Cruelty                 2003  Miles                       1
# ...

# %%
c = cast[cast.name == 'George Clooney']
c.groupby(['title', 'year']).size()
# Out:
# title                               year
# A Very Murray Christmas             2015    1
# Batman & Robin                      1997    2
# Burn After Reading                  2008    1
# Confessions of a Dangerous Mind     2002    1
# Curdled                             1996    1
# Fantastic Mr. Fox                   2009    1
# From Dusk Till Dawn                 1996    1
# Good Night, and Good Luck.          2005    1
# Gravity                             2013    1
# Hail, Caesar!                       2016    1
# Intolerable Cruelty                 2003    1
# Leatherheads                        2008    1
# Michael Clayton                     2007    1
# Money Monster                       2016    1
# Morning Glory                       2010    1
# O Brother, Where Art Thou?          2000    1
# Ocean's Eleven                      2001    1
# Ocean's Thirteen                    2007    1
# Ocean's Twelve                      2004    1
# ...

# %%
c.groupby(['year']).size().plot(kind='bar')

# %%
c.groupby('year').n.min()
# Out:
# year
# 1987    15.0
# 1988     2.0
# 1992     5.0
# 1996     1.0
# 1997     1.0
# 1998     1.0
# 1999     1.0
# 2000     1.0
# 2001     1.0
# 2002     1.0
# 2003     1.0
# 2004     3.0
# 2005     2.0
# 2006     1.0
# 2007     1.0
# 2008     1.0
# 2009     1.0
# 2010     1.0
# 2011     1.0
# 2013     2.0
# 2014     1.0
# 2015     1.0
# 2016     1.0
# Name: n, dtype: float64

# %% [markdown]
# # Section 4:
#
# ## Contents:
#
# - df.unstack()
# - df.stack()
# - df.fillna(value)

# %%
c.groupby('year').n.max()
# Out:
# year
# 1987    15.0
# 1988     2.0
# 1992    23.0
# 1996     2.0
# 1997     2.0
# 1998    14.0
# 1999    11.0
# 2000     1.0
# 2001    36.0
# 2002    17.0
# 2003    22.0
# 2004     3.0
# 2005    15.0
# 2006     1.0
# 2007     6.0
# 2008     5.0
# 2009     1.0
# 2010     1.0
# 2011     2.0
# 2013     2.0
# 2014     1.0
# 2015     4.0
# 2016     2.0
# Name: n, dtype: float64

# %%
#number of films per decade
c.groupby(c.year // 10 * 10).size()
# Out:
# year
# 1980     2
# 1990    14
# 2000    20
# 2010    11
# dtype: int64

# %%
c = cast
c.groupby([c.year // 10 * 10, 'type']).size()
# Out:
# year  type
# 1890  actor           2
#       actress         1
# 1900  actor          54
#       actress        16
# 1910  actor       27099
#       actress     15484
# 1920  actor       47783
#       actress     23526
# 1930  actor      149800
#       actress     49060
# 1940  actor      160460
#       actress     50911
# 1950  actor      154727
#       actress     56259
# 1960  actor      130593
#       actress     55862
# 1970  actor      149433
#       actress     64843
# 1980  actor      193482
#       actress     89223
# 1990  actor      258799
#       actress    122359
# 2000  actor      484890
#       actress    260766
# 2010  actor      682777
#       actress    382812
# 2020  actor         129
#       actress        62
# dtype: int64

# %%
c = cast
c.groupby(['type', c.year // 10 * 10]).size()
# Out:
# type     year
# actor    1890         2
#          1900        54
#          1910     27099
#          1920     47783
#          1930    149800
#          1940    160460
#          1950    154727
#          1960    130593
#          1970    149433
#          1980    193482
#          1990    258799
#          2000    484890
#          2010    682777
#          2020       129
# actress  1890         1
#          1900        16
#          1910     15484
#          1920     23526
#          1930     49060
#          1940     50911
#          1950     56259
#          1960     55862
#          1970     64843
#          1980     89223
#          1990    122359
#          2000    260766
#          2010    382812
#          2020        62
# dtype: int64

# %%
c = cast
c = c[(c.character == 'Kermit the Frog') |
      (c.character == 'Oscar the Grouch')]
c
# Out:
#                                                   title  year            name  \
# 947844                   An American Werewolf in London  1981      Jim Henson
# 947845                                 Follow That Bird  1985      Jim Henson
# 947850                           The Great Muppet Caper  1981      Jim Henson
# 947858                                 The Muppet Movie  1979      Jim Henson
# 947865                       The Muppets Take Manhattan  1984      Jim Henson
# 2078314                                Follow That Bird  1985  Caroll Spinney
# 2078317  Night at the Museum: Battle of the Smithsonian  2009  Caroll Spinney
# 2078319            The Adventures of Elmo in Grouchland  1999  Caroll Spinney
# 2078320                          The Great Muppet Caper  1981  Caroll Spinney
# 2349148                  Mr. Magorium's Wonder Emporium  2007  Steve Whitmire
# 2349149                          Muppet Treasure Island  1996  Steve Whitmire
# ...

# %%
g = c.groupby(['character', c.year // 10 * 10]).size()
g
# Out:
# character         year
# Kermit the Frog   1970    1
#                   1980    4
#                   1990    2
#                   2000    1
#                   2010    1
# Oscar the Grouch  1980    2
#                   1990    1
#                   2000    1
# dtype: int64

# %%
g.unstack()
# Out:
# year              1970  1980  1990  2000  2010
# character
# Kermit the Frog    1.0   4.0   2.0   1.0   1.0
# Oscar the Grouch   NaN   2.0   1.0   1.0   NaN

# %%
g.unstack('year')
# Out:
# year              1970  1980  1990  2000  2010
# character
# Kermit the Frog    1.0   4.0   2.0   1.0   1.0
# Oscar the Grouch   NaN   2.0   1.0   1.0   NaN

# %%
g.unstack(0)
# Out:
# character  Kermit the Frog  Oscar the Grouch
# year
# 1970                   1.0               NaN
# 1980                   4.0               2.0
# 1990                   2.0               1.0
# 2000                   1.0               1.0
# 2010                   1.0               NaN

# %%
u = g.unstack('character')
u
# Out:
# character  Kermit the Frog  Oscar the Grouch
# year
# 1970                   1.0               NaN
# 1980                   4.0               2.0
# 1990                   2.0               1.0
# 2000                   1.0               1.0
# 2010                   1.0               NaN

# %%
u.stack()
# Out:
# year  character
# 1970  Kermit the Frog     1.0
# 1980  Kermit the Frog     4.0
#       Oscar the Grouch    2.0
# 1990  Kermit the Frog     2.0
#       Oscar the Grouch    1.0
# 2000  Kermit the Frog     1.0
#       Oscar the Grouch    1.0
# 2010  Kermit the Frog     1.0
# dtype: float64

# %%
u.unstack()
# Out:
# character         year
# Kermit the Frog   1970    1.0
#                   1980    4.0
#                   1990    2.0
#                   2000    1.0
#                   2010    1.0
# Oscar the Grouch  1970    NaN
#                   1980    2.0
#                   1990    1.0
#                   2000    1.0
#                   2010    NaN
# dtype: float64

# %%
u['Kermit the Frog'] - u['Oscar the Grouch']
# Out:
# year
# 1970    NaN
# 1980    2.0
# 1990    1.0
# 2000    0.0
# 2010    NaN
# dtype: float64

# %%
u.fillna(0)
# Out:
# character  Kermit the Frog  Oscar the Grouch  extra
# year
# 1970                   1.0               0.0      1
# 1980                   4.0               2.0      1
# 1990                   2.0               1.0      1
# 2000                   1.0               1.0      1
# 2010                   1.0               0.0      1

# %%
g
# Out:
# character         year
# Kermit the Frog   1970    1
#                   1980    4
#                   1990    2
#                   2000    1
#                   2010    1
# Oscar the Grouch  1980    2
#                   1990    1
#                   2000    1
# dtype: int64

# %%
g.unstack('character').unstack('year')
# Out:
# character         year
# Kermit the Frog   1970    1.0
#                   1980    4.0
#                   1990    2.0
#                   2000    1.0
#                   2010    1.0
# Oscar the Grouch  1970    NaN
#                   1980    2.0
#                   1990    1.0
#                   2000    1.0
#                   2010    NaN
# dtype: float64

# %%
u['extra'] = 1
u
# Out:
# character  Kermit the Frog  Oscar the Grouch  extra
# year
# 1970                   1.0               NaN      1
# 1980                   4.0               2.0      1
# 1990                   2.0               1.0      1
# 2000                   1.0               1.0      1
# 2010                   1.0               NaN      1

# %%
u = u.set_index('extra', drop=True, append=True)
u
# Out:
# character   Kermit the Frog  Oscar the Grouch
# year extra
# 1970 1                  1.0               NaN
# 1980 1                  4.0               2.0
# 1990 1                  2.0               1.0
# 2000 1                  1.0               1.0
# 2010 1                  1.0               NaN

# %%
u.unstack('year')
# Out:
# character Kermit the Frog                     Oscar the Grouch                 \
# year                 1970 1980 1990 2000 2010             1970 1980 1990 2000
# extra
# 1                     1.0  4.0  2.0  1.0  1.0              NaN  2.0  1.0  1.0
#
# character
# year      2010
# extra
# 1          NaN

# %% [markdown]
# # Section 5:
#
# ## Contents:
#
# - s.dt.day() .month()  .year()  .dayofweek()  .dayofmonth()  .dayofyear()
# - df.pivot()
# - df.merge()

# %%
release_dates = pd.DataFrame.from_csv('data/release_dates.csv', index_col=None,
                                      parse_dates=['date'], infer_datetime_format=True)
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                 #Beings  2015      Romania 2015-01-29
# 2               #Declimax  2018  Netherlands 2018-01-21
# 3  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21
# 4                 #Horror  2015          USA 2015-11-20

# %%
r = release_dates
r.date.dt.year
# Out:
# 0         2007
# 1         2015
# 2         2018
# 3         2015
# 4         2015
# 5         2016
# 6         2015
# 7         2014
# 8         2016
# 9         2017
# 10        2017
# 11        2016
# 12        2014
# 13        2014
# 14        2017
# 15        2016
# 16        2014
# 17        2015
# 18        1972
# 19        1972
# 20        1972
# 21        1972
# 22        1972
# 23        1972
# 24        1972
# 25        1972
# 26        1972
# 27        1973
# 28        1973
# 29        1935
#           ...
# 449831    2005
# 449832    2005
# 449833    2005
# 449834    2005
# 449835    2005
# 449836    2005
# 449837    2005
# 449838    2005
# 449839    2005
# 449840    2005
# 449841    2005
# 449842    2005
# 449843    2005
# 449844    2005
# 449845    2005
# 449846    2005
# 449847    2005
# 449848    2005
# 449849    2005
# 449850    2005
# 449851    2005
# 449852    2005
# 449853    2005
# 449854    2005
# 449855    2005
# 449856    2005
# 449857    2005
# ...

# %%
r.date.dt.month
# Out:
# 0          6
# 1          1
# 2          1
# 3          1
# 4         11
# 5          5
# 6          9
# 7          2
# 8          7
# 9          3
# 10        10
# 11        10
# 12         7
# 13        10
# 14         9
# 15         5
# 16        12
# 17        11
# 18         2
# 19         3
# 20         3
# 21         5
# 22         9
# 23         9
# 24         9
# 25        10
# 26        10
# 27         1
# 28        11
# 29         5
#           ..
# 449831     4
# 449832     4
# 449833     4
# 449834     4
# 449835     4
# 449836     4
# 449837     4
# 449838     4
# 449839     4
# 449840     4
# 449841     4
# 449842     4
# 449843     4
# 449844     4
# 449845     4
# 449846     4
# 449847     4
# 449848     4
# 449849     4
# 449850     4
# 449851     4
# 449852     4
# 449853     4
# 449854     4
# 449855     4
# 449856     4
# 449857     6
# 449858     6
# 449859     6
# 449860     6
# Name: date, dtype: int64

# %%
r.date.dt.day
# Out:
# 0         15
# 1         29
# 2         21
# 3         21
# 4         20
# 5         16
# 6          1
# 7         13
# 8         29
# 9          1
# 10        31
# 11         1
# 12         1
# 13        10
# 14        14
# 15         6
# 16        10
# 17        12
# 18        17
# 19        10
# 20        27
# 21         5
# 22        12
# 23        13
# 24        14
# 25         7
# 26        18
# 27        26
# 28        19
# 29         4
#           ..
# 449831    28
# 449832    28
# 449833    28
# 449834    28
# 449835    28
# 449836    28
# 449837    28
# 449838    28
# 449839    28
# 449840    28
# 449841    28
# 449842    28
# 449843    28
# 449844    28
# 449845    29
# 449846    29
# 449847    29
# 449848    29
# 449849    29
# 449850    29
# 449851    29
# 449852    29
# 449853    29
# 449854    29
# 449855    29
# 449856    29
# 449857     3
# 449858     3
# 449859    17
# 449860    24
# Name: date, dtype: int64

# %%
r.date.dt.dayofyear
# Out:
# 0         166
# 1          29
# 2          21
# 3          21
# 4         324
# 5         137
# 6         244
# 7          44
# 8         211
# 9          60
# 10        304
# 11        275
# 12        182
# 13        283
# 14        257
# 15        127
# 16        344
# 17        316
# 18         48
# 19         70
# 20         87
# 21        126
# 22        256
# 23        257
# 24        258
# 25        281
# 26        292
# 27         26
# 28        323
# 29        124
#          ...
# 449831    118
# 449832    118
# 449833    118
# 449834    118
# 449835    118
# 449836    118
# 449837    118
# 449838    118
# 449839    118
# 449840    118
# 449841    118
# 449842    118
# 449843    118
# 449844    118
# 449845    119
# 449846    119
# 449847    119
# 449848    119
# 449849    119
# 449850    119
# 449851    119
# 449852    119
# 449853    119
# 449854    119
# 449855    119
# 449856    119
# 449857    154
# 449858    154
# 449859    168
# 449860    175
# ...

# %%
r.date.dt.dayofweek
# Out:
# 0         4
# 1         3
# 2         6
# 3         2
# 4         4
# 5         0
# 6         1
# 7         3
# 8         4
# 9         2
# 10        1
# 11        5
# 12        1
# 13        4
# 14        3
# 15        4
# 16        2
# 17        3
# 18        3
# 19        4
# 20        0
# 21        4
# 22        1
# 23        2
# 24        3
# 25        5
# 26        2
# 27        4
# 28        0
# 29        5
#          ..
# 449831    3
# 449832    3
# 449833    3
# 449834    3
# 449835    3
# 449836    3
# 449837    3
# 449838    3
# 449839    3
# 449840    3
# 449841    3
# 449842    3
# 449843    3
# 449844    3
# 449845    4
# 449846    4
# 449847    4
# 449848    4
# 449849    4
# 449850    4
# 449851    4
# 449852    4
# 449853    4
# 449854    4
# 449855    4
# 449856    4
# 449857    4
# 449858    4
# 449859    4
# 449860    4
# Name: date, dtype: int64

# %%
r = release_dates
r = r[r.title.str.startswith('Star Wars: Episode')]
r = r[r.country.str.startswith('U')]
r.head()
# Out:
#                                                title  year  \
# 321977     Star Wars: Episode I - The Phantom Menace  1999
# 321998     Star Wars: Episode I - The Phantom Menace  1999
# 322007     Star Wars: Episode I - The Phantom Menace  1999
# 322024     Star Wars: Episode I - The Phantom Menace  1999
# 322087  Star Wars: Episode II - Attack of the Clones  2002
#
#                      country       date
# 321977                   USA 1999-05-19
# 321998               Uruguay 1999-07-02
# 322007                    UK 1999-07-15
# 322024  United Arab Emirates 1999-08-25
# 322087                    UK 2002-05-16

# %%
r.pivot('title', 'country', 'date')
# Out:
# country                                                UK        USA  \
# title
# Star Wars: Episode I - The Phantom Menace      1999-07-15 1999-05-19
# Star Wars: Episode II - Attack of the Clones   2002-05-16 2002-05-16
# Star Wars: Episode III - Revenge of the Sith   2005-05-19 2005-05-19
# Star Wars: Episode IX                                 NaT 2019-05-24
# Star Wars: Episode V - The Empire Strikes Back 1980-05-21 1980-06-20
# Star Wars: Episode VI - Return of the Jedi     1983-06-02 1983-05-25
# Star Wars: Episode VII - The Force Awakens     2015-12-17 2015-12-18
# Star Wars: Episode VIII                        2017-12-15 2017-12-15
#
# country                                           Ukraine  \
# title
# Star Wars: Episode I - The Phantom Menace             NaT
# Star Wars: Episode II - Attack of the Clones   2002-06-08
# Star Wars: Episode III - Revenge of the Sith          NaT
# Star Wars: Episode IX                                 NaT
# ...

# %%
c = cast
c = c[c.n<=2]
c = c[c.name == 'Cary Grant']
c.head()
# Out:
#                         title  year        name   type          character    n
# 840335  An Affair to Remember  1957  Cary Grant  actor    Nickie Ferrante  1.0
# 840336   Arsenic and Old Lace  1944  Cary Grant  actor  Mortimer Brewster  1.0
# 840337         Big Brown Eyes  1936  Cary Grant  actor         Danny Barr  1.0
# 840339         Born to Be Bad  1934  Cary Grant  actor     Malcolm Trevor  2.0
# 840340       Bringing Up Baby  1938  Cary Grant  actor              David  2.0

# %%
c = c.merge(cast, on=['title', 'year'])
c[(c.n_y <= 2)]
# Out:
#                              title  year      name_x type_x  \
# 15           An Affair to Remember  1957  Cary Grant  actor
# 63           An Affair to Remember  1957  Cary Grant  actor
# 88            Arsenic and Old Lace  1944  Cary Grant  actor
# 108           Arsenic and Old Lace  1944  Cary Grant  actor
# 127                 Big Brown Eyes  1936  Cary Grant  actor
# 159                 Big Brown Eyes  1936  Cary Grant  actor
# 186                 Born to Be Bad  1934  Cary Grant  actor
# 211                 Born to Be Bad  1934  Cary Grant  actor
# 230               Bringing Up Baby  1938  Cary Grant  actor
# 258               Bringing Up Baby  1938  Cary Grant  actor
# 284                        Charade  1963  Cary Grant  actor
# 302                        Charade  1963  Cary Grant  actor
# 318                         Crisis  1950  Cary Grant  actor
# 327                         Crisis  1950  Cary Grant  actor
# 392              Destination Tokyo  1943  Cary Grant  actor
# ...

# %%
c[(c.n_y <= 2) & (c.name_x != c.name_y)]
# Out:
#                                      title  year      name_x type_x  \
# 63                   An Affair to Remember  1957  Cary Grant  actor
# 108                   Arsenic and Old Lace  1944  Cary Grant  actor
# 159                         Big Brown Eyes  1936  Cary Grant  actor
# 211                         Born to Be Bad  1934  Cary Grant  actor
# 258                       Bringing Up Baby  1938  Cary Grant  actor
# 302                                Charade  1963  Cary Grant  actor
# 318                                 Crisis  1950  Cary Grant  actor
# 392                      Destination Tokyo  1943  Cary Grant  actor
# 512                             Dream Wife  1953  Cary Grant  actor
# 543                          Enter Madame!  1935  Cary Grant  actor
# 569           Every Girl Should Be Married  1948  Cary Grant  actor
# 605                           Father Goose  1964  Cary Grant  actor
# 636                          Gambling Ship  1933  Cary Grant  actor
# ...

# %% [markdown]
# # Section 6:
